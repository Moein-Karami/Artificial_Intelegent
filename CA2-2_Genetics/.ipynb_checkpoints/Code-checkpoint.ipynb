# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 26px; color: blue">
#         <b>
#             پروژه دوم درس هوش مصنوعی
#             <br>
#             <br>
#             Genetics
#         </b>
#     </div>
# <br>
# <br>
# <br>
#     <div dir = "rtl" style="font-size: 24px; color: gray">
#         <b>
#             معین کرمی
#             <br>
#             <br>
#             810198540
#         </b>
#     </div>
# </html>

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             هدف پروژه:
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#         <b>
#             <br>
#             در این پروژه با الگوریتم های ژنتیک آشنا می‌شویم که بر گرفته از طبیعت و انتخاب های طبیعی هستند و معمولا در مسئله هایی که فضای بزرگی دارند استفاده می‌شود.
#         <br>
#         <br>
#     </div>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             خلاصه ی مسئله:
#         </b>
#     </div>
#     <br>
#     <div dir = "rtl" style = "font-size: 16px">
#             در این مسئله یک متن طولانی و یک متن رمز گذاری شده به ما داده می‌شود که ما باید با استفاده از متن طولانی یک دیکشنری ساخته و سپس با استفاده از این دیکشنری متن رمز گذاری شده را
#         decode
#         کنیم و به متن اولیه برسیم.
#     </div>
# </html>

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             بخش 0: تمیز کردن داده ها و ایجاد لغت نامه
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#             <br>
#             در اینجا
#             stop word
#             ها را حذف نمی‌کنیم چون این کلمات نیز معنی دار هستند و فقط علائم نگارشی و اعداد را حذف می‌کنیم(به (
#         عبارت دیگر فقط حروف الفبا رو  نگه می‌داریم)
#         برای اینکار تمام کاراکتر هایی که جزو الفبا نیسیتند را حذف می‌کنیم و به جای بقیه کاراکتر ها اسپیس می‌گذاریم و در نهایت کلمه های متن را به یک دیکشنری اضافه می‌کنیم.
#             <br>
#         <br>
#     </div>
# </html>

# %%
CONSTANT = 14
class Decoder:
    def __init__(self, global_text, encoded_text, keyLength = CONSTANT):
        self.global_text = global_text
        self.encoded_text = encoded_text
        self.key_len = keyLength
        
    def creat_dict(self):
        clean_text = ""
        for char in self.global_text:
            if char.isalpha():
                clean_text += char
            else:
                clean_text += ' '
        clean_text = clean_text.split()
        self.dict = dict()
        for word in clean_text:
            self.dict[word] = True

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             بخش یک: مشخص کردن مفاهیم اولیه
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#             <br>
#             هر کروموزم را شامل ۱۴ ژنتیک تعریف می‌کنیم که هر ژنتیک معادل یک حرف است و خود کروموزم نشان دهنده کلید ما است.
#             <br>
#         <br>
#     </div>
# </html>

# %%
import random
import string
class Chromosome:
    def __init__(self, key_len):
        self.genetics = []
        for i in range(key_len):
            self.genetics.append(random.choice(string.ascii_letters).lower())
    
    def __lt__(self, other):
        return self.genetics < other.genetics

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             بخش دوم: تولید جمعیت اولیه
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#             <br>
#             برای جمعیت اولیه ۱۰۰۰ کروموزوم می‌سازیم:
#             <br>
#         <br>
#     </div>
# </html>

# %%
NUMBER_OF_INITIAL_POPULATION = 400
def creat_initial_population(self, number_of_initial_population = NUMBER_OF_INITIAL_POPULATION):
    self.chromosomes = []
    self.number_of_initial_population = number_of_initial_population
    for i in range(self.number_of_initial_population):
        self.chromosomes.append(Chromosome(self.key_len))
Decoder.creat_initial_population = creat_initial_population

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             بخش سوم: پیاده سازی و مشخص کردن تابع معیار سازگاری
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#             <br>
#             پیاده سازی و مشخص کردن تابع معیار سازگاری:
#         تابع معیار سازگاری را تعداد کلمات معنا داری تعریف می‌کنیم که با استفاده از کروموزوم از متن کد شده به دست می‌اید. کلمات معنی دار را کلمات داخل دیکشنری که در ابتدا ساختیم تعریف ‌می‌کنیم.
#             <br>
#         <br>
#     </div>
# </html>

# %%
def get_score(self, key):
    key_index = 0
    decoded_text = ""
    for char in self.encoded_text:
        if char.isalpha():
            decoded_text += self.get_real_char(char, key[key_index])
            key_index += 1
            key_index %= len(key)
        else:
            decoded_text += " "
    decoded_words = decoded_text.split()
    return (self.calculate_score(decoded_words), len(decoded_words))

def get_real_char(self, char, key_char):
    capital = char.isupper()
    char.lower()
    ascii_code = ord(char) - (ord(key_char) - ord('a'))
    if ascii_code < ord('a'):
        ascii_code += ord('z') - ord('a') + 1
    real_char = chr(ascii_code)
    if capital:
        real_char.upper()
    return real_char

def calculate_score(self, decoded_words):
    score = 0
    for word in decoded_words:
        if word in self.dict:
            score += 1
    return score

Decoder.get_score = get_score
Decoder.get_real_char = get_real_char
Decoder.calculate_score = calculate_score

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             بخش چهارم:پیاده سازی
#             crossover
#             و
#             mutation
#             و تولید جمعیت بعدی
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#             <br>
#             ابتدا بر اساس امتیاز هر کروموزوم، کروموزوم هارا رتبه بندی می‌کنیم و به هر کروموزوم بر اساس رنک آن شانسی برای حضور در جمعیت بعدی را می‌دهیم.
#         <br>
#         حال مجموعه جدید را شافل می‌کنیم تا ترتیب ها به هم بریزد.
#         <br>
#         سپس به احتمال
#         $p_c$
#         عمل
#         cross over
#         را روی دو کروموزوم متوالی اعمال می‌کنیم. در عمل
#         cross over
#         میان دو کروموزوم، هر ژن را به احتمال
#         $p_g$
#         جا به جا می‌کنیم.
#         <br>
#         در نهایت عمل
#         mutation
#         رار روی هر کروموزوم انجام می‌دهیم که در آن هر ژن به احتمال
#         $p_m$
#         عوض می‌شود و با احتمال برابر تبذیل به یکی از حروف الفبا می‌شود.
#         <br>
#         توجه داشته باشید چون کروموزوم های بهتر با احتمال بیشتری در جمعیت بعدی قرار می‌گیرند، احتمال انتقال آن ها بدون تغییر به نسل بعدی نیز بیشتر از باقی کروموزوم ها است.
#             <br>
#         <br>
#     </div>
# </html>

# %%
PC = 0.9
PG = 0.5
PM = 0.05

def creat_new_population(self, pc = PC, pg = PG, pm = PM):
    chromosomes = self.get_new_population()
    random.shuffle(chromosomes)
    ###
#     print("here it is")
#     for i in chromosomes:
#         print (i.genetics)
#     print("__________")
    ###
    self.chromosomes = []
    for i in range(0, len(chromosomes), 2):
        if random.random() <= pc:
            self.chromosomes.append(chromosomes[i].cross_over(chromosomes[i + 1], PG))
            self.chromosomes.append(chromosomes[i])
        else:
            self.chromosomes.append(chromosomes[i])
            self.chromosomes.append(chromosomes[i + 1])
    
    ###
#     print("self is here")
#     for i in self.chromosomes:
#         print (i.genetics)
#     print("****************")
    ###
    mx = 0
    for i in range(len(self.chromosomes)):
        chromosomes[i].mutation(PM)
        ###
        mx = max(mx, self.get_score(chromosomes[i].genetics)[0])
        ###
    print(f"max is {mx}")
        
def get_new_population(self):
    score_list = []
    for chromosome in self.chromosomes:
        score_list.append(150 + self.get_score(chromosome.genetics)[0])
    chromosomes = random.choices(self.chromosomes, weights = None, cum_weights = score_list, k = len(self.chromosomes))
    return chromosomes

Decoder.creat_new_population = creat_new_population
Decoder.get_new_population = get_new_population


def cross_over(self, chromosome, chance):
    for i in range(len(self.genetics)):
        if random.random() <= chance:
            self.genetics[i], chromosome.genetics[i] = chromosome.genetics[i], self.genetics[i]
    return chromosome

def mutation(self, chance):
    for i in range(len(self.genetics)):
        if random.random() <= chance:
            self.genetics[i] = random.choice(string.ascii_letters).lower()

Chromosome.cross_over = cross_over
Chromosome.mutation = mutation

# %% [markdown]
# <html>
#     <div dir = "rtl" style="font-size: 22px; color: green">
#         <b>
#             بخش پنجم: ایجاد الگوریتم ژنتیک روی مسئله
#         </b>
#     </div>
#     <div dir = "rtl" style = "font-size: 16px">
#     </div>
# </html>

# %%
def decode(self):
    self.creat_dict()
    self.creat_initial_population()
    for i in range(100000):
        ###
        print(f'turn {i}')
        ###
        done = self.code_is_breaked()
        ###
        print(f'turnII: {i}')
        ###
        if done >= 0:
            return translate(self.chromosoms[done])
        self.creat_new_population()

def code_is_breaked(self):
    index = -1;
    for chromosome in self.chromosomes:
        index += 1
        check = self.get_score(chromosome.genetics)
        if (check[0] == check[1]):
            return index
    return -1

def translate(self, key):
    key_index = 0
    decoded_text = ""
    for char in self.encoded_text:
        if char.isalpha():
            decoded_text += self.get_real_char(char, key[key_index])
            key_index += 1
            key_index %= len(key)
        else:
            decoded_text += char
    return decoded_text

Decoder.decode = decode
Decoder.code_is_breaked = code_is_breaked
Decoder.translate = translate

# %%
encodedText=open('encoded_text.txt').read()
globalText=open('global_text.txt').read()
d = Decoder(globalText,encodedText, keyLength=CONSTANT)
decodedText=d.decode()
# Out:
# turn 0
# turnII: 0
# max is 23
# turn 1
# turnII: 1
# max is 21
# turn 2
# turnII: 2
# max is 27
# turn 3
# turnII: 3
# max is 26
# turn 4
# turnII: 4
# max is 27
# turn 5
# turnII: 5
# max is 27
# turn 6
# turnII: 6
# max is 24
# turn 7
# turnII: 7
# max is 29
# turn 8
# turnII: 8
# max is 24
# turn 9
# turnII: 9
# max is 24
# turn 10
# turnII: 10
# max is 25
# turn 11
# turnII: 11
# max is 26
# turn 12
# turnII: 12
# max is 22
# turn 13
# turnII: 13
# max is 26
# turn 14
# turnII: 14
# max is 21
# turn 15
# turnII: 15
# max is 35
# turn 16
# turnII: 16
# max is 25
# turn 17
# turnII: 17
# max is 25
# turn 18
# turnII: 18
# max is 22
# turn 19
# turnII: 19
# max is 28
# turn 20
# turnII: 20
# max is 25
# turn 21
# turnII: 21
# max is 24
# turn 22
# turnII: 22
# max is 31
# turn 23
# turnII: 23
# max is 45
# turn 24
# turnII: 24
# max is 25
# turn 25
# turnII: 25
# max is 26
# turn 26
# turnII: 26
# max is 28
# turn 27
# turnII: 27
# max is 30
# turn 28
# turnII: 28
# max is 31
# turn 29
# turnII: 29
# max is 25
# turn 30
# turnII: 30
# max is 29
# turn 31
# turnII: 31
# max is 28
# turn 32
# turnII: 32
# max is 27
# turn 33
# turnII: 33
# max is 32
# turn 34
# turnII: 34
# max is 28
# turn 35
# turnII: 35
# max is 27
# turn 36
# turnII: 36
# max is 22
# turn 37
# turnII: 37
# max is 31
# turn 38
# turnII: 38
# max is 22
# turn 39
# turnII: 39
# max is 23
# turn 40
# turnII: 40
# max is 26
# turn 41
# turnII: 41
# max is 26
# turn 42
# turnII: 42
# max is 26
# turn 43
# turnII: 43
# max is 25
# turn 44
# turnII: 44
# max is 21
# turn 45
# turnII: 45
# max is 32
# turn 46
# turnII: 46
# max is 28
# turn 47
# turnII: 47
# max is 30
# turn 48
# turnII: 48
# max is 33
# turn 49
# turnII: 49
# max is 29
# turn 50
# turnII: 50
# max is 24
# turn 51
# turnII: 51
# max is 25
# turn 52
# turnII: 52
# max is 27
# turn 53
# turnII: 53
# max is 25
# turn 54
# turnII: 54
# max is 24
# turn 55
# turnII: 55
# max is 28
# turn 56
# turnII: 56
# max is 24
# turn 57
# turnII: 57
# max is 26
# turn 58
# turnII: 58
# max is 24
# turn 59
# turnII: 59
# max is 26
# turn 60
# turnII: 60
# max is 23
# turn 61
# turnII: 61
# max is 23
# turn 62
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-955fc507e978> in <module>
#       2 globalText=open('global_text.txt').read()
#       3 d = Decoder(globalText,encodedText, keyLength=CONSTANT)
# ----> 4 decodedText=d.decode()
#
# <ipython-input-6-12cef2b59839> in decode(self)
#       6         print(f'turn {i}')
#       7         ###
# ----> 8         done = self.code_is_breaked()
#       9         ###
#      10         print(f'turnII: {i}')
#
# <ipython-input-6-12cef2b59839> in code_is_breaked(self)
#      18     for chromosome in self.chromosomes:
#      19         index += 1
# ---> 20         check = self.get_score(chromosome.genetics)
#      21         if (check[0] == check[1]):
#      22             return index
#
# <ipython-input-4-43dff4eeded5> in get_score(self, key)
#       4     for char in self.encoded_text:
#       5         if char.isalpha():
# ----> 6             decoded_text += self.get_real_char(char, key[key_index])
#       7             key_index += 1
#       8             key_index %= len(key)
#
# <ipython-input-4-43dff4eeded5> in get_real_char(self, char, key_char)
#      16     char.lower()
#      17     ascii_code = ord(char) - (ord(key_char) - ord('a'))
# ---> 18     if ascii_code < ord('a'):
#      19         ascii_code += ord('z') - ord('a') + 1
#      20     real_char = chr(ascii_code)
#
# KeyboardInterrupt:
